# %%
import psycopg2

import pandas.io.sql as psql
import numpy as np
import pandas as pd
import parser as pr

#from xlwt import easyxf, Borders, Workbook, Pattern, Style


def data_connection(conn_string):
    conn = psycopg2.connect(conn_string)
    return conn


def data_frame(query, connection):
    df = psql.frame_query(query, con=connection)   
    return df


def crosstabulate(report):
    conn = data_connection(report["conn_str"])
    df = data_frame(report["query"], conn)

    groups = report['groups']
    aggregates = report['aggregates']
    agg = {groups[0]: ['Grand Total']}

    for a in aggregates:
        agg[a[0]] = getattr(df[a[0]], a[1])()
    total = pd.DataFrame(agg)
    total['total_rank'] = 1
    dfs = [total]

    for i in range(1, len(groups)):
        parent_group = groups[:i]
        child_group = groups[i]
        group_total = df.groupby(parent_group, as_index=False).sum()
        group_total[child_group] = group_total[parent_group[-1]].apply(label)
        group_total[parent_group[-1] + '_rank'] = 1
        dfs.append(group_total)
    dfs.append(df.groupby(groups, as_index=False).sum())
    #print dfs[2].to_string()

    # UNION the DataFrames into one DataFrame
    result = pd.concat(dfs)

    # Replace NaNs with empty strings
    result.fillna(dict([(x, '') for x in groups]), inplace=True)
    groups_sort = []
    for x in reversed(groups[:-1]):
        groups_sort.append(result[x + '_rank'].rank())
        groups_sort.append(result[x].rank())
    groups_sort.append(result['total_rank'].rank())

    # Reorder the rows
    sorter = np.lexsort((groups_sort))
    result = result.take(sorter)
    result = result.reindex(columns=groups + [x[0] for x in aggregates])
    return result


def label(ser):
    return '{s} Total'.format(s=ser)


if True:
    reports = pr.parse_tryp("inventory_by_sku.tryp")
    for report in reports:
        ct = crosstabulate(report)
        #print ct.to_string(index=False)

# %%
def label(ser):
    return '{s} Total'.format(s=ser)
pd.set_printoptions(max_columns=100)

# %%
reports = pr.parse_tryp("inventory_by_sku.tryp")
report = reports[1]
conn = data_connection(report["conn_str"])
df = data_frame(report["query"], conn)


columns = ['Region Parent', 'Region', 'Distributor']
rows = ['Category','Brand','SKU']
aggregates=['Sales Qty','Sales Value']
df_items = []

def subcolumns(df_cols, group_length, reverse=False):                                                                                                                                       
                                                                                                                                                                             
    subcols= []                                                                                                                                                               
    for i, col in enumerate(df_cols):                                                                                                                        
        subcols.append(col)                                                                                                                                                      
        if i < len(df_cols) - 1:                                                                                                                           
            for j in reversed(range(-(group_length-1), 0)):                                                                                                                   
                if df_cols[i+1][:j]!=col[:j]:                                                                                                                
                   subcols.append(col[:j])                                                                                                                                      
        else:                                                                                                                                                                
            for j in reversed(range(-(group_length-1), 0)):                                                                                                                   
                subcols.append(col[:j])
    if reverse:        
        return sorted(reversed(subcols))        
    else:        
        return subcols

for i, cols in enumerate(subcolumns(sorted(df.groupby(columns).groups.keys()),len(columns))):    
    for agg in aggregates:
        group = df.groupby(rows + columns[:len(cols)]).sum().unstack(columns[:len(cols)])[agg]      +  
        key = (agg,) + cols
        if len(cols) == 1:          
            df_items.append((key, group[cols[0]]))
        else:              
            df_items.append((key, group[cols]))
    

df = pd.DataFrame.from_items(df_items)

# %%
items = []

for index in subcolumns(df.index, len(rows)):         
    if len(index) < len(rows):                
        items.append((index, np.sum(df.ix[index].fillna(0).values,axis=0)))
    else:        
        items.append((index, df.ix[index]))

tet = pd.DataFrame.from_items(items, orient='index', columns=df.columns)
tet.to_csv('/tmp/tet.csv')

# %%
tet
# Out:
#                                    (Sales Qty, Peninsular Malaysia, Central, K.Lumpur/P.Jaya)  \
# (FNDM, Ambient Milk/STM, 1151000)                                          97.500000
# (FNDM, Ambient Milk/STM, 1151001)                                           2.000000
# (FNDM, Ambient Milk/STM, 1151002)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151003)                                                NaN
# (FNDM, Ambient Milk/STM, 1151004)                                                NaN
# (FNDM, Ambient Milk/STM, 1151005)                                          97.500000
# (FNDM, Ambient Milk/STM, 1151006)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151007)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151008)                                                NaN
# (FNDM, Ambient Milk/STM, 1151009)                                          88.000000
# (FNDM, Ambient Milk/STM, 1151010)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151011)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151012)                                           1.000000
# (FNDM, Ambient Milk/STM, 1151016)                                                NaN
# (FNDM, Ambient Milk/STM)                                                  286.000000
# (FNDM, EVAP, 1110225)                                                            NaN
# (FNDM, EVAP, 1111503)                                                   10600.937500
# (FNDM, EVAP, 1111516)                                                    1039.541667
# (FNDM, EVAP, 1111517)                                                     245.729167
# (FNDM, EVAP, 1111518)                                                            NaN
# (FNDM, EVAP, 1111536)                                                    1098.937500
# (FNDM, EVAP, 1111545)                                                    3086.687500
# (FNDM, EVAP, 1111741)                                                       0.250000
# (FNDM, EVAP, 1111742)                                                       0.000000
# (FNDM, EVAP)                                                            16072.083333
# (FNDM, SBC, 1111501)                                                        0.000000
# (FNDM, SBC, 1111502)                                                      218.708333
# (FNDM, SBC, 1111521)                                                             NaN
# (FNDM, SBC, 1111523)                                                        0.770833
# (FNDM, SBC, 1111524)                                                             NaN
# (FNDM, SBC, 1111528)                                                     1137.125000
# (FNDM, SBC, 1111529)                                                             NaN
# (FNDM, SBC, 1111530)                                                        0.000000
# (FNDM, SBC, 1111531)                                                             NaN
# (FNDM, SBC, 1111534)                                                        0.000000
# (FNDM, SBC, 1111539)                                                             NaN
# (FNDM, SBC, 1111541)                                                             NaN
# (FNDM, SBC, 1111542)                                                             NaN
# (FNDM, SBC, 1111555)                                                       -1.416667
# (FNDM, SBC, 1111556)                                                     1906.500000
# (FNDM, SBC, 1111559)                                                       -0.041667
# (FNDM, SBC, 1111781)                                                     3063.500000
# (FNDM, SBC, 1111799)                                                      537.187500
# (FNDM, SBC, 1111804)                                                      506.770833
# (FNDM, SBC, 1111813)                                                             NaN
# (FNDM, SBC, 1111817)                                                        0.000000
# (FNDM, SBC, 1111823)                                                     5128.479167
# (FNDM, SBC, 1111824)                                                     6090.791667
# (FNDM, SBC, 1111826)                                                      175.000000
# (FNDM, SBC, 1111829)                                                      480.541667
# (FNDM, SBC, 1111830)                                                    24041.583333
# (FNDM, SBC, 1111832)                                                     2304.020833
# (FNDM, SBC, 1111844)                                                      470.000000
# (FNDM, SBC, 1111870)                                                             NaN
# (FNDM, SBC, 1111877)                                                      380.500000
# (FNDM, SBC)                                                             46440.020833
# (FNDM, SCM, 1111519)                                                      385.000000
# (FNDM, SCM)                                                               385.000000
# (FNDM, UHT, 1150028)                                                             NaN
# (FNDM, UHT)                                                                 0.000000
# (FNDM)                                                                  63183.104167
#
#                                    (Sales Value, Peninsular Malaysia, Central, K.Lumpur/P.Jaya)  \
# (FNDM, Ambient Milk/STM, 1151000)                                        3580.200000
# (FNDM, Ambient Milk/STM, 1151001)                                          73.440000
# (FNDM, Ambient Milk/STM, 1151002)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151003)                                                NaN
# (FNDM, Ambient Milk/STM, 1151004)                                                NaN
# (FNDM, Ambient Milk/STM, 1151005)                                        6107.400000
# (FNDM, Ambient Milk/STM, 1151006)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151007)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151008)                                                NaN
# (FNDM, Ambient Milk/STM, 1151009)                                        6415.200000
# (FNDM, Ambient Milk/STM, 1151010)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151011)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151012)                                          72.900000
# (FNDM, Ambient Milk/STM, 1151016)                                                NaN
# (FNDM, Ambient Milk/STM)                                                16249.140000
# (FNDM, EVAP, 1110225)                                                            NaN
# (FNDM, EVAP, 1111503)                                                 1303229.879180
# (FNDM, EVAP, 1111516)                                                  127029.075000
# (FNDM, EVAP, 1111517)                                                   32992.462505
# (FNDM, EVAP, 1111518)                                                            NaN
# (FNDM, EVAP, 1111536)                                                  122947.907914
# (FNDM, EVAP, 1111545)                                                  487449.690000
# (FNDM, EVAP, 1111741)                                                      36.480000
# (FNDM, EVAP, 1111742)                                                       0.000000
# (FNDM, EVAP)                                                          2073685.494599
# (FNDM, SBC, 1111501)                                                        0.000000
# (FNDM, SBC, 1111502)                                                    29080.766670
# (FNDM, SBC, 1111521)                                                             NaN
# (FNDM, SBC, 1111523)                                                      100.670833
# (FNDM, SBC, 1111524)                                                             NaN
# (FNDM, SBC, 1111528)                                                    98201.850000
# (FNDM, SBC, 1111529)                                                             NaN
# (FNDM, SBC, 1111530)                                                        0.000000
# (FNDM, SBC, 1111531)                                                             NaN
# (FNDM, SBC, 1111534)                                                        0.000000
# (FNDM, SBC, 1111539)                                                             NaN
# (FNDM, SBC, 1111541)                                                             NaN
# (FNDM, SBC, 1111542)                                                             NaN
# (FNDM, SBC, 1111555)                                                     -204.680000
# (FNDM, SBC, 1111556)                                                   165975.750000
# (FNDM, SBC, 1111559)                                                       -6.220000
# (FNDM, SBC, 1111781)                                                   365843.147132
# (FNDM, SBC, 1111799)                                                    70156.687491
# (FNDM, SBC, 1111804)                                                    69808.416656
# (FNDM, SBC, 1111813)                                                             NaN
# (FNDM, SBC, 1111817)                                                     -834.399999
# (FNDM, SBC, 1111823)                                                   562681.708196
# (FNDM, SBC, 1111824)                                                   648634.612845
# (FNDM, SBC, 1111826)                                                    19914.999997
# (FNDM, SBC, 1111829)                                                    63920.200008
# (FNDM, SBC, 1111830)                                                  2601146.882988
# (FNDM, SBC, 1111832)                                                   289258.820815
# (FNDM, SBC, 1111844)                                                    61381.999992
# (FNDM, SBC, 1111870)                                                             NaN
# (FNDM, SBC, 1111877)                                                    47446.125000
# (FNDM, SBC)                                                           5092507.338626
# (FNDM, SCM, 1111519)                                                    64125.600000
# (FNDM, SCM)                                                             64125.600000
# (FNDM, UHT, 1150028)                                                             NaN
# (FNDM, UHT)                                                                 0.000000
# (FNDM)                                                                7246567.573225
#
#                                    (Sales Qty, Peninsular Malaysia, Central, Seremban)  \
# (FNDM, Ambient Milk/STM, 1151000)                                                NaN
# (FNDM, Ambient Milk/STM, 1151001)                                                NaN
# (FNDM, Ambient Milk/STM, 1151002)                                                NaN
# (FNDM, Ambient Milk/STM, 1151003)                                                NaN
# (FNDM, Ambient Milk/STM, 1151004)                                                NaN
# (FNDM, Ambient Milk/STM, 1151005)                                                NaN
# (FNDM, Ambient Milk/STM, 1151006)                                                NaN
# (FNDM, Ambient Milk/STM, 1151007)                                                NaN
# (FNDM, Ambient Milk/STM, 1151008)                                                NaN
# (FNDM, Ambient Milk/STM, 1151009)                                                NaN
# (FNDM, Ambient Milk/STM, 1151010)                                                NaN
# (FNDM, Ambient Milk/STM, 1151011)                                                NaN
# (FNDM, Ambient Milk/STM, 1151012)                                                NaN
# (FNDM, Ambient Milk/STM, 1151016)                                                NaN
# (FNDM, Ambient Milk/STM)                                                    0.000000
# (FNDM, EVAP, 1110225)                                                      92.000000
# (FNDM, EVAP, 1111503)                                                    1037.375000
# (FNDM, EVAP, 1111516)                                                     440.000000
# (FNDM, EVAP, 1111517)                                                     340.000000
# (FNDM, EVAP, 1111518)                                                            NaN
# (FNDM, EVAP, 1111536)                                                     198.000000
# (FNDM, EVAP, 1111545)                                                     406.187500
# (FNDM, EVAP, 1111741)                                                      -6.500000
# (FNDM, EVAP, 1111742)                                                            NaN
# (FNDM, EVAP)                                                             2507.062500
# (FNDM, SBC, 1111501)                                                             NaN
# (FNDM, SBC, 1111502)                                                      187.541667
# (FNDM, SBC, 1111521)                                                             NaN
# (FNDM, SBC, 1111523)                                                             NaN
# (FNDM, SBC, 1111524)                                                             NaN
# (FNDM, SBC, 1111528)                                                     1791.000000
# (FNDM, SBC, 1111529)                                                             NaN
# (FNDM, SBC, 1111530)                                                       67.000000
# (FNDM, SBC, 1111531)                                                             NaN
# (FNDM, SBC, 1111534)                                                       39.000000
# (FNDM, SBC, 1111539)                                                             NaN
# (FNDM, SBC, 1111541)                                                             NaN
# (FNDM, SBC, 1111542)                                                       64.000000
# (FNDM, SBC, 1111555)                                                             NaN
# (FNDM, SBC, 1111556)                                                      278.000000
# (FNDM, SBC, 1111559)                                                             NaN
# (FNDM, SBC, 1111781)                                                      185.875000
# (FNDM, SBC, 1111799)                                                        2.000000
# (FNDM, SBC, 1111804)                                                       24.500000
# (FNDM, SBC, 1111813)                                                             NaN
# (FNDM, SBC, 1111817)                                                             NaN
# (FNDM, SBC, 1111823)                                                     2031.000000
# (FNDM, SBC, 1111824)                                                      664.000000
# (FNDM, SBC, 1111826)                                                        1.000000
# (FNDM, SBC, 1111829)                                                      209.395833
# (FNDM, SBC, 1111830)                                                     1879.770833
# (FNDM, SBC, 1111832)                                                      222.625000
# (FNDM, SBC, 1111844)                                                       96.000000
# (FNDM, SBC, 1111870)                                                             NaN
# (FNDM, SBC, 1111877)                                                        0.000000
# (FNDM, SBC)                                                              7742.708333
# (FNDM, SCM, 1111519)                                                       10.000000
# (FNDM, SCM)                                                                10.000000
# (FNDM, UHT, 1150028)                                                             NaN
# (FNDM, UHT)                                                                 0.000000
# (FNDM)                                                                  10259.770833
#
#                                    (Sales Value, Peninsular Malaysia, Central, Seremban)  \
# (FNDM, Ambient Milk/STM, 1151000)                                                NaN
# (FNDM, Ambient Milk/STM, 1151001)                                                NaN
# (FNDM, Ambient Milk/STM, 1151002)                                                NaN
# (FNDM, Ambient Milk/STM, 1151003)                                                NaN
# (FNDM, Ambient Milk/STM, 1151004)                                                NaN
# (FNDM, Ambient Milk/STM, 1151005)                                                NaN
# (FNDM, Ambient Milk/STM, 1151006)                                                NaN
# (FNDM, Ambient Milk/STM, 1151007)                                                NaN
# (FNDM, Ambient Milk/STM, 1151008)                                                NaN
# (FNDM, Ambient Milk/STM, 1151009)                                                NaN
# (FNDM, Ambient Milk/STM, 1151010)                                                NaN
# (FNDM, Ambient Milk/STM, 1151011)                                                NaN
# (FNDM, Ambient Milk/STM, 1151012)                                                NaN
# (FNDM, Ambient Milk/STM, 1151016)                                                NaN
# (FNDM, Ambient Milk/STM)                                                    0.000000
# (FNDM, EVAP, 1110225)                                                   14103.600000
# (FNDM, EVAP, 1111503)                                                  126835.663750
# (FNDM, EVAP, 1111516)                                                   54004.000000
# (FNDM, EVAP, 1111517)                                                   46206.000000
# (FNDM, EVAP, 1111518)                                                            NaN
# (FNDM, EVAP, 1111536)                                                   22374.199997
# (FNDM, EVAP, 1111545)                                                   64084.560000
# (FNDM, EVAP, 1111741)                                                    -904.580000
# (FNDM, EVAP, 1111742)                                                            NaN
# (FNDM, EVAP)                                                           326703.443747
# (FNDM, SBC, 1111501)                                                             NaN
# (FNDM, SBC, 1111502)                                                    24896.290005
# (FNDM, SBC, 1111521)                                                             NaN
# (FNDM, SBC, 1111523)                                                             NaN
# (FNDM, SBC, 1111524)                                                             NaN
# (FNDM, SBC, 1111528)                                                   156354.300000
# (FNDM, SBC, 1111529)                                                             NaN
# (FNDM, SBC, 1111530)                                                     9379.999997
# (FNDM, SBC, 1111531)                                                             NaN
# (FNDM, SBC, 1111534)                                                     4539.000001
# (FNDM, SBC, 1111539)                                                             NaN
# (FNDM, SBC, 1111541)                                                             NaN
# (FNDM, SBC, 1111542)                                                     6890.000000
# (FNDM, SBC, 1111555)                                                             NaN
# (FNDM, SBC, 1111556)                                                    24434.700000
# (FNDM, SBC, 1111559)                                                             NaN
# (FNDM, SBC, 1111781)                                                    22194.722503
# (FNDM, SBC, 1111799)                                                      261.200000
# (FNDM, SBC, 1111804)                                                     3437.999999
# (FNDM, SBC, 1111813)                                                             NaN
# (FNDM, SBC, 1111817)                                                             NaN
# (FNDM, SBC, 1111823)                                                   222478.999940
# (FNDM, SBC, 1111824)                                                    70730.800000
# (FNDM, SBC, 1111826)                                                      116.000000
# (FNDM, SBC, 1111829)                                                    27793.055838
# (FNDM, SBC, 1111830)                                                   200781.015085
# (FNDM, SBC, 1111832)                                                    27698.349996
# (FNDM, SBC, 1111844)                                                    12537.599998
# (FNDM, SBC, 1111870)                                                             NaN
# (FNDM, SBC, 1111877)                                                        0.000000
# (FNDM, SBC)                                                            814524.033362
# (FNDM, SCM, 1111519)                                                     1599.000000
# (FNDM, SCM)                                                              1599.000000
# (FNDM, UHT, 1150028)                                                             NaN
# (FNDM, UHT)                                                                 0.000000
# (FNDM)                                                                1142826.477110
#
#                                    (Sales Qty, Peninsular Malaysia, Central)  \
# (FNDM, Ambient Milk/STM, 1151000)                                  97.500000
# (FNDM, Ambient Milk/STM, 1151001)                                   2.000000
# (FNDM, Ambient Milk/STM, 1151002)                                   0.000000
# (FNDM, Ambient Milk/STM, 1151003)                                        NaN
# (FNDM, Ambient Milk/STM, 1151004)                                        NaN
# (FNDM, Ambient Milk/STM, 1151005)                                  97.500000
# (FNDM, Ambient Milk/STM, 1151006)                                   0.000000
# (FNDM, Ambient Milk/STM, 1151007)                                   0.000000
# (FNDM, Ambient Milk/STM, 1151008)                                        NaN
# (FNDM, Ambient Milk/STM, 1151009)                                  88.000000
# (FNDM, Ambient Milk/STM, 1151010)                                   0.000000
# (FNDM, Ambient Milk/STM, 1151011)                                   0.000000
# (FNDM, Ambient Milk/STM, 1151012)                                   1.000000
# (FNDM, Ambient Milk/STM, 1151016)                                        NaN
# (FNDM, Ambient Milk/STM)                                          286.000000
# (FNDM, EVAP, 1110225)                                              92.000000
# (FNDM, EVAP, 1111503)                                           11638.312500
# (FNDM, EVAP, 1111516)                                            1479.541667
# (FNDM, EVAP, 1111517)                                             585.729167
# (FNDM, EVAP, 1111518)                                                    NaN
# (FNDM, EVAP, 1111536)                                            1296.937500
# (FNDM, EVAP, 1111545)                                            3492.875000
# (FNDM, EVAP, 1111741)                                              -6.250000
# (FNDM, EVAP, 1111742)                                               0.000000
# (FNDM, EVAP)                                                    18579.145833
# (FNDM, SBC, 1111501)                                                0.000000
# (FNDM, SBC, 1111502)                                              406.250000
# (FNDM, SBC, 1111521)                                                     NaN
# (FNDM, SBC, 1111523)                                                0.770833
# (FNDM, SBC, 1111524)                                                     NaN
# (FNDM, SBC, 1111528)                                             2928.125000
# (FNDM, SBC, 1111529)                                                     NaN
# (FNDM, SBC, 1111530)                                               67.000000
# (FNDM, SBC, 1111531)                                                     NaN
# (FNDM, SBC, 1111534)                                               39.000000
# (FNDM, SBC, 1111539)                                                     NaN
# (FNDM, SBC, 1111541)                                                     NaN
# (FNDM, SBC, 1111542)                                               64.000000
# (FNDM, SBC, 1111555)                                               -1.416667
# (FNDM, SBC, 1111556)                                             2184.500000
# (FNDM, SBC, 1111559)                                               -0.041667
# (FNDM, SBC, 1111781)                                             3249.375000
# (FNDM, SBC, 1111799)                                              539.187500
# (FNDM, SBC, 1111804)                                              531.270833
# (FNDM, SBC, 1111813)                                                     NaN
# (FNDM, SBC, 1111817)                                                0.000000
# (FNDM, SBC, 1111823)                                             7159.479167
# (FNDM, SBC, 1111824)                                             6754.791667
# (FNDM, SBC, 1111826)                                              176.000000
# (FNDM, SBC, 1111829)                                              689.937500
# (FNDM, SBC, 1111830)                                            25921.354167
# (FNDM, SBC, 1111832)                                             2526.645833
# (FNDM, SBC, 1111844)                                              566.000000
# (FNDM, SBC, 1111870)                                                     NaN
# (FNDM, SBC, 1111877)                                              380.500000
# (FNDM, SBC)                                                     54182.729167
# (FNDM, SCM, 1111519)                                              395.000000
# (FNDM, SCM)                                                       395.000000
# (FNDM, UHT, 1150028)                                                     NaN
# (FNDM, UHT)                                                         0.000000
# (FNDM)                                                          73442.875000
#
#                                    (Sales Value, Peninsular Malaysia, Central)  \
# (FNDM, Ambient Milk/STM, 1151000)                                  3580.200000
# (FNDM, Ambient Milk/STM, 1151001)                                    73.440000
# (FNDM, Ambient Milk/STM, 1151002)                                     0.000000
# (FNDM, Ambient Milk/STM, 1151003)                                          NaN
# (FNDM, Ambient Milk/STM, 1151004)                                          NaN
# (FNDM, Ambient Milk/STM, 1151005)                                  6107.400000
# (FNDM, Ambient Milk/STM, 1151006)                                     0.000000
# (FNDM, Ambient Milk/STM, 1151007)                                     0.000000
# (FNDM, Ambient Milk/STM, 1151008)                                          NaN
# (FNDM, Ambient Milk/STM, 1151009)                                  6415.200000
# (FNDM, Ambient Milk/STM, 1151010)                                     0.000000
# (FNDM, Ambient Milk/STM, 1151011)                                     0.000000
# (FNDM, Ambient Milk/STM, 1151012)                                    72.900000
# (FNDM, Ambient Milk/STM, 1151016)                                          NaN
# (FNDM, Ambient Milk/STM)                                          16249.140000
# (FNDM, EVAP, 1110225)                                             14103.600000
# (FNDM, EVAP, 1111503)                                           1430065.542930
# (FNDM, EVAP, 1111516)                                            181033.075000
# (FNDM, EVAP, 1111517)                                             79198.462505
# (FNDM, EVAP, 1111518)                                                      NaN
# (FNDM, EVAP, 1111536)                                            145322.107911
# (FNDM, EVAP, 1111545)                                            551534.250000
# (FNDM, EVAP, 1111741)                                              -868.100000
# (FNDM, EVAP, 1111742)                                                 0.000000
# (FNDM, EVAP)                                                    2400388.938347
# (FNDM, SBC, 1111501)                                                  0.000000
# (FNDM, SBC, 1111502)                                              53977.056675
# (FNDM, SBC, 1111521)                                                       NaN
# (FNDM, SBC, 1111523)                                                100.670833
# (FNDM, SBC, 1111524)                                                       NaN
# (FNDM, SBC, 1111528)                                             254556.150000
# (FNDM, SBC, 1111529)                                                       NaN
# (FNDM, SBC, 1111530)                                               9379.999997
# (FNDM, SBC, 1111531)                                                       NaN
# (FNDM, SBC, 1111534)                                               4539.000001
# (FNDM, SBC, 1111539)                                                       NaN
# (FNDM, SBC, 1111541)                                                       NaN
# (FNDM, SBC, 1111542)                                               6890.000000
# (FNDM, SBC, 1111555)                                               -204.680000
# (FNDM, SBC, 1111556)                                             190410.450000
# (FNDM, SBC, 1111559)                                                 -6.220000
# (FNDM, SBC, 1111781)                                             388037.869636
# (FNDM, SBC, 1111799)                                              70417.887491
# (FNDM, SBC, 1111804)                                              73246.416655
# (FNDM, SBC, 1111813)                                                       NaN
# (FNDM, SBC, 1111817)                                               -834.399999
# (FNDM, SBC, 1111823)                                             785160.708136
# (FNDM, SBC, 1111824)                                             719365.412845
# (FNDM, SBC, 1111826)                                              20030.999997
# (FNDM, SBC, 1111829)                                              91713.255846
# (FNDM, SBC, 1111830)                                            2801927.898073
# (FNDM, SBC, 1111832)                                             316957.170811
# (FNDM, SBC, 1111844)                                              73919.599991
# (FNDM, SBC, 1111870)                                                       NaN
# (FNDM, SBC, 1111877)                                              47446.125000
# (FNDM, SBC)                                                     5907031.371988
# (FNDM, SCM, 1111519)                                              65724.600000
# (FNDM, SCM)                                                       65724.600000
# (FNDM, UHT, 1150028)                                                       NaN
# (FNDM, UHT)                                                           0.000000
# (FNDM)                                                          8389394.050334
#
#                                    (Sales Qty, Peninsular Malaysia, East Coast, Kota Bahru)  \
# (FNDM, Ambient Milk/STM, 1151000)                                           7.833333
# (FNDM, Ambient Milk/STM, 1151001)                                          10.333333
# (FNDM, Ambient Milk/STM, 1151002)                                           6.833333
# (FNDM, Ambient Milk/STM, 1151003)                                                NaN
# (FNDM, Ambient Milk/STM, 1151004)                                                NaN
# (FNDM, Ambient Milk/STM, 1151005)                                          79.000000
# (FNDM, Ambient Milk/STM, 1151006)                                          10.000000
# (FNDM, Ambient Milk/STM, 1151007)                                          10.000000
# (FNDM, Ambient Milk/STM, 1151008)                                                NaN
# (FNDM, Ambient Milk/STM, 1151009)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151010)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151011)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151012)                                                NaN
# (FNDM, Ambient Milk/STM, 1151016)                                                NaN
# (FNDM, Ambient Milk/STM)                                                  124.000000
# (FNDM, EVAP, 1110225)                                                            NaN
# (FNDM, EVAP, 1111503)                                                      82.729167
# (FNDM, EVAP, 1111516)                                                     347.291667
# (FNDM, EVAP, 1111517)                                                       1.000000
# (FNDM, EVAP, 1111518)                                                       0.000000
# (FNDM, EVAP, 1111536)                                                      83.500000
# (FNDM, EVAP, 1111545)                                                      97.500000
# (FNDM, EVAP, 1111741)                                                      -0.354167
# (FNDM, EVAP, 1111742)                                                            NaN
# (FNDM, EVAP)                                                              611.666667
# (FNDM, SBC, 1111501)                                                             NaN
# (FNDM, SBC, 1111502)                                                             NaN
# (FNDM, SBC, 1111521)                                                             NaN
# (FNDM, SBC, 1111523)                                                             NaN
# (FNDM, SBC, 1111524)                                                             NaN
# (FNDM, SBC, 1111528)                                                       15.000000
# (FNDM, SBC, 1111529)                                                             NaN
# (FNDM, SBC, 1111530)                                                             NaN
# (FNDM, SBC, 1111531)                                                             NaN
# (FNDM, SBC, 1111534)                                                             NaN
# (FNDM, SBC, 1111539)                                                             NaN
# (FNDM, SBC, 1111541)                                                             NaN
# (FNDM, SBC, 1111542)                                                             NaN
# (FNDM, SBC, 1111555)                                                      221.125000
# (FNDM, SBC, 1111556)                                                             NaN
# (FNDM, SBC, 1111559)                                                       -8.625000
# (FNDM, SBC, 1111781)                                                      728.375000
# (FNDM, SBC, 1111799)                                                       80.500000
# (FNDM, SBC, 1111804)                                                     2569.520833
# (FNDM, SBC, 1111813)                                                             NaN
# (FNDM, SBC, 1111817)                                                             NaN
# (FNDM, SBC, 1111823)                                                             NaN
# (FNDM, SBC, 1111824)                                                             NaN
# (FNDM, SBC, 1111826)                                                    12143.500000
# (FNDM, SBC, 1111829)                                                             NaN
# (FNDM, SBC, 1111830)                                                     6478.250000
# (FNDM, SBC, 1111832)                                                             NaN
# (FNDM, SBC, 1111844)                                                             NaN
# (FNDM, SBC, 1111870)                                                             NaN
# (FNDM, SBC, 1111877)                                                             NaN
# (FNDM, SBC)                                                             22227.645833
# (FNDM, SCM, 1111519)                                                             NaN
# (FNDM, SCM)                                                                 0.000000
# (FNDM, UHT, 1150028)                                                             NaN
# (FNDM, UHT)                                                                 0.000000
# (FNDM)                                                                  22963.312500
#
#                                    (Sales Value, Peninsular Malaysia, East Coast, Kota Bahru)  \
# (FNDM, Ambient Milk/STM, 1151000)                                         287.640000
# (FNDM, Ambient Milk/STM, 1151001)                                         379.440000
# (FNDM, Ambient Milk/STM, 1151002)                                         250.920000
# (FNDM, Ambient Milk/STM, 1151003)                                                NaN
# (FNDM, Ambient Milk/STM, 1151004)                                                NaN
# (FNDM, Ambient Milk/STM, 1151005)                                        4948.560000
# (FNDM, Ambient Milk/STM, 1151006)                                         626.400000
# (FNDM, Ambient Milk/STM, 1151007)                                         626.400000
# (FNDM, Ambient Milk/STM, 1151008)                                                NaN
# (FNDM, Ambient Milk/STM, 1151009)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151010)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151011)                                           0.000000
# (FNDM, Ambient Milk/STM, 1151012)                                                NaN
# (FNDM, Ambient Milk/STM, 1151016)                                                NaN
# (FNDM, Ambient Milk/STM)                                                 7119.360000
# (FNDM, EVAP, 1110225)                                                            NaN
# (FNDM, EVAP, 1111503)                                                   10048.755000
# (FNDM, EVAP, 1111516)                                                   41741.337500
# (FNDM, EVAP, 1111517)                                                     133.000000
# (FNDM, EVAP, 1111518)                                                       0.000000
# (FNDM, EVAP, 1111536)                                                    9235.800001
# (FNDM, EVAP, 1111545)                                                   15399.730000
# (FNDM, EVAP, 1111741)                                                     -50.490000
# (FNDM, EVAP, 1111742)                                                            NaN
# (FNDM, EVAP)                                                            76508.132501
# (FNDM, SBC, 1111501)                                                             NaN
# (FNDM, SBC, 1111502)                                                             NaN
# (FNDM, SBC, 1111521)                                                             NaN
# (FNDM, SBC, 1111523)                                                             NaN
# (FNDM, SBC, 1111524)                                                             NaN
# (FNDM, SBC, 1111528)                                                     1440.000000
# (FNDM, SBC, 1111529)                                                             NaN
# (FNDM, SBC, 1111530)                                                             NaN
# (FNDM, SBC, 1111531)                                                             NaN
# (FNDM, SBC, 1111534)                                                             NaN
# (FNDM, SBC, 1111539)                                                             NaN
# (FNDM, SBC, 1111541)                                                             NaN
# (FNDM, SBC, 1111542)                                                             NaN
# (FNDM, SBC, 1111555)                                                    23620.289999
# (FNDM, SBC, 1111556)                                                             NaN
# (FNDM, SBC, 1111559)                                                    -1057.910000
# (FNDM, SBC, 1111781)                                                    85525.650011
# (FNDM, SBC, 1111799)                                                    10513.299999
# (FNDM, SBC, 1111804)                                                   349608.374959
# (FNDM, SBC, 1111813)                                                             NaN
# (FNDM, SBC, 1111817)                                                             NaN
# (FNDM, SBC, 1111823)                                                             NaN
# (FNDM, SBC, 1111824)                                                             NaN
# (FNDM, SBC, 1111826)                                                  1382741.899808
# (FNDM, SBC, 1111829)                                                             NaN
# (FNDM, SBC, 1111830)                                                   685725.601354
# (FNDM, SBC, 1111832)                                                             NaN
# (FNDM, SBC, 1111844)                                                             NaN
# (FNDM, SBC, 1111870)                                                             NaN
# (FNDM, SBC, 1111877)                                                             NaN
# (FNDM, SBC)                                                           2538117.206131
# (FNDM, SCM, 1111519)                                                             NaN
# (FNDM, SCM)                                                                 0.000000
# (FNDM, UHT, 1150028)                                                             NaN
# (FNDM, UHT)                                                                 0.000000
# (FNDM)                                                                2621744.698632
#
#                                    (Sales Qty, Peninsular Malaysia, East Coast, Kuala Terengganu)  \
# (FNDM, Ambient Milk/STM, 1151000)                                          39.916667
# (FNDM, Ambient Milk/STM, 1151001)                                         101.291667
# (FNDM, Ambient Milk/STM, 1151002)                                          91.500000
# (FNDM, Ambient Milk/STM, 1151003)                                          27.458333
# (FNDM, Ambient Milk/STM, 1151004)                                          26.291667
# (FNDM, Ambient Milk/STM, 1151005)                                          34.583333
# (FNDM, Ambient Milk/STM, 1151006)                                          84.208333
# (FNDM, Ambient Milk/STM, 1151007)                                          73.333333
# (FNDM, Ambient Milk/STM, 1151008)                                          21.333333
# (FNDM, Ambient Milk/STM, 1151009)                                           7.200000
# (FNDM, Ambient Milk/STM, 1151010)                                          12.733333
# (FNDM, Ambient Milk/STM, 1151011)                                          12.733333
# (FNDM, Ambient Milk/STM, 1151012)                                           4.466667
# (FNDM, Ambient Milk/STM, 1151016)                                                NaN
# (FNDM, Ambient Milk/STM)                                                  537.050000
# (FNDM, EVAP, 1110225)                                                            NaN
# (FNDM, EVAP, 1111503)                                                            NaN
# (FNDM, EVAP, 1111516)                                                     405.041667
# (FNDM, EVAP, 1111517)                                                      25.104167
# (FNDM, EVAP, 1111518)                                                            NaN
# (FNDM, EVAP, 1111536)                                                     130.270833
# (FNDM, EVAP, 1111545)                                                            NaN
# (FNDM, EVAP, 1111741)                                                            NaN
# (FNDM, EVAP, 1111742)                                                            NaN
# ...
# (FNDM, SBC, 1111542)                                                 3.000000
# (FNDM, SBC, 1111555)                                              2643.541667
# (FNDM, SBC, 1111556)                                              6766.125000
# (FNDM, SBC, 1111559)                                                55.500000
# (FNDM, SBC, 1111781)                                              3220.916667
# (FNDM, SBC, 1111799)                                              1492.770833
# (FNDM, SBC, 1111804)                                              8303.187500
# (FNDM, SBC, 1111813)                                               122.041667
# (FNDM, SBC, 1111817)                                                      NaN
# (FNDM, SBC, 1111823)                                              3680.687500
# (FNDM, SBC, 1111824)                                             23949.625000
# (FNDM, SBC, 1111826)                                              7861.687500
# (FNDM, SBC, 1111829)                                                87.291667
# (FNDM, SBC, 1111830)                                             10572.479167
# (FNDM, SBC, 1111832)                                              3124.520833
# (FNDM, SBC, 1111844)                                              1528.895833
# (FNDM, SBC, 1111870)                                                      NaN
# (FNDM, SBC, 1111877)                                               215.000000
# (FNDM, SBC)                                                      82209.833333
# (FNDM, SCM, 1111519)                                                      NaN
# (FNDM, SCM)                                                          0.000000
# (FNDM, UHT, 1150028)                                                      NaN
# (FNDM, UHT)                                                          0.000000
# (FNDM)                                                          111844.166667
#
#                                    (Sales Value, Peninsular Malaysia, Southern)  \
# (FNDM, Ambient Milk/STM, 1151000)                                  18585.355831
# (FNDM, Ambient Milk/STM, 1151001)                                   7109.773333
# (FNDM, Ambient Milk/STM, 1151002)                                   5511.561666
# (FNDM, Ambient Milk/STM, 1151003)                                     17.650000
# (FNDM, Ambient Milk/STM, 1151004)                                      0.000000
# (FNDM, Ambient Milk/STM, 1151005)                                  51867.948329
# (FNDM, Ambient Milk/STM, 1151006)                                  13860.259166
# (FNDM, Ambient Milk/STM, 1151007)                                   8692.863333
# (FNDM, Ambient Milk/STM, 1151008)                                    121.000000
# (FNDM, Ambient Milk/STM, 1151009)                                  50664.263336
# (FNDM, Ambient Milk/STM, 1151010)                                   1601.070000
# (FNDM, Ambient Milk/STM, 1151011)                                   1744.680000
# (FNDM, Ambient Milk/STM, 1151012)                                    -36.560000
# (FNDM, Ambient Milk/STM, 1151016)                                      0.000000
# (FNDM, Ambient Milk/STM)                                          159739.864994
# (FNDM, EVAP, 1110225)                                              11625.250000
# (FNDM, EVAP, 1111503)                                            2317596.974652
# (FNDM, EVAP, 1111516)                                             423416.965059
# (FNDM, EVAP, 1111517)                                              92360.075015
# (FNDM, EVAP, 1111518)                                              10191.450000
# (FNDM, EVAP, 1111536)                                             265443.888325
# (FNDM, EVAP, 1111545)                                             177428.890000
# (FNDM, EVAP, 1111741)                                              19041.700000
# (FNDM, EVAP, 1111742)                                                       NaN
# (FNDM, EVAP)                                                     3317105.193051
# (FNDM, SBC, 1111501)                                                   0.000000
# (FNDM, SBC, 1111502)                                              306885.516706
# (FNDM, SBC, 1111521)                                                 -51.920000
# (FNDM, SBC, 1111523)                                                 462.660000
# (FNDM, SBC, 1111524)                                                 -45.600000
# (FNDM, SBC, 1111528)                                              283824.100000
# (FNDM, SBC, 1111529)                                               30074.779992
# (FNDM, SBC, 1111530)                                               29578.999994
# (FNDM, SBC, 1111531)                                               22542.097500
# (FNDM, SBC, 1111534)                                              274397.902079
# (FNDM, SBC, 1111539)                                                   0.000000
# (FNDM, SBC, 1111541)                                                        NaN
# (FNDM, SBC, 1111542)                                                 176.600000
# (FNDM, SBC, 1111555)                                              281910.874169
# (FNDM, SBC, 1111556)                                              590904.287500
# (FNDM, SBC, 1111559)                                                7629.223332
# (FNDM, SBC, 1111781)                                              384323.148804
# (FNDM, SBC, 1111799)                                              194981.748309
# (FNDM, SBC, 1111804)                                             1143306.640719
# (FNDM, SBC, 1111813)                                               16258.740002
# (FNDM, SBC, 1111817)                                                        NaN
# (FNDM, SBC, 1111823)                                              431939.774075
# (FNDM, SBC, 1111824)                                             2601513.072696
# (FNDM, SBC, 1111826)                                              890599.182498
# (FNDM, SBC, 1111829)                                               11591.230001
# (FNDM, SBC, 1111830)                                             1150736.518710
# (FNDM, SBC, 1111832)                                              388890.225137
# (FNDM, SBC, 1111844)                                              199422.793307
# (FNDM, SBC, 1111870)                                                        NaN
# (FNDM, SBC, 1111877)                                               26122.500000
# (FNDM, SBC)                                                      9267975.095529
# (FNDM, SCM, 1111519)                                                        NaN
# (FNDM, SCM)                                                            0.000000
# (FNDM, UHT, 1150028)                                                        NaN
# (FNDM, UHT)                                                            0.000000
# (FNDM)                                                          12744820.153574
#
#                                    (Sales Qty, Peninsular Malaysia)  \
# (FNDM, Ambient Milk/STM, 1151000)                       2170.250000
# (FNDM, Ambient Milk/STM, 1151001)                        745.416667
# (FNDM, Ambient Milk/STM, 1151002)                        647.041667
# (FNDM, Ambient Milk/STM, 1151003)                        -47.916667
# (FNDM, Ambient Milk/STM, 1151004)                         26.291667
# (FNDM, Ambient Milk/STM, 1151005)                       3459.625000
# (FNDM, Ambient Milk/STM, 1151006)                        570.500000
# (FNDM, Ambient Milk/STM, 1151007)                        437.583333
# (FNDM, Ambient Milk/STM, 1151008)                         29.333333
# (FNDM, Ambient Milk/STM, 1151009)                       3910.400000
# (FNDM, Ambient Milk/STM, 1151010)                         71.933333
# (FNDM, Ambient Milk/STM, 1151011)                         71.533333
# (FNDM, Ambient Milk/STM, 1151012)                         19.933333
# (FNDM, Ambient Milk/STM, 1151016)                          0.000000
# (FNDM, Ambient Milk/STM)                               12111.925000
# (FNDM, EVAP, 1110225)                                    234.833333
# (FNDM, EVAP, 1111503)                                  42587.270833
# (FNDM, EVAP, 1111516)                                  10333.708333
# (FNDM, EVAP, 1111517)                                   1911.979167
# (FNDM, EVAP, 1111518)                                    108.625000
# (FNDM, EVAP, 1111536)                                   6723.333333
# (FNDM, EVAP, 1111545)                                   7429.625000
# (FNDM, EVAP, 1111741)                                    130.562500
# (FNDM, EVAP, 1111742)                                     28.291667
# (FNDM, EVAP)                                           69488.229167
# (FNDM, SBC, 1111501)                                      15.500000
# (FNDM, SBC, 1111502)                                    3597.333333
# (FNDM, SBC, 1111521)                                      22.583333
# (FNDM, SBC, 1111523)                                      38.916667
# (FNDM, SBC, 1111524)                                      -0.937500
# (FNDM, SBC, 1111528)                                    9609.000000
# (FNDM, SBC, 1111529)                                    1032.520833
# (FNDM, SBC, 1111530)                                     716.229167
# (FNDM, SBC, 1111531)                                     689.875000
# (FNDM, SBC, 1111534)                                    2873.166667
# (FNDM, SBC, 1111539)                                      46.000000
# (FNDM, SBC, 1111541)                                      -0.354167
# (FNDM, SBC, 1111542)                                    6139.187500
# (FNDM, SBC, 1111555)                                    4451.333333
# (FNDM, SBC, 1111556)                                   13128.000000
# (FNDM, SBC, 1111559)                                     149.354167
# (FNDM, SBC, 1111781)                                   13600.416667
# (FNDM, SBC, 1111799)                                    3538.020833
# (FNDM, SBC, 1111804)                                   15790.687500
# (FNDM, SBC, 1111813)                                     416.041667
# (FNDM, SBC, 1111817)                                       0.000000
# (FNDM, SBC, 1111823)                                   21377.333333
# (FNDM, SBC, 1111824)                                   61082.666667
# (FNDM, SBC, 1111826)                                   30496.520833
# (FNDM, SBC, 1111829)                                     782.729167
# (FNDM, SBC, 1111830)                                   71645.416667
# (FNDM, SBC, 1111832)                                   12138.770833
# (FNDM, SBC, 1111844)                                    3401.333333
# (FNDM, SBC, 1111870)                                       0.000000
# (FNDM, SBC, 1111877)                                     614.500000
# (FNDM, SBC)                                           277392.145833
# (FNDM, SCM, 1111519)                                     394.979167
# (FNDM, SCM)                                              394.979167
# (FNDM, UHT, 1150028)                                      98.000000
# (FNDM, UHT)                                               98.000000
# (FNDM)                                                359485.279167
#
#                                    (Sales Value, Peninsular Malaysia)
# (FNDM, Ambient Milk/STM, 1151000)                        77441.015820
# (FNDM, Ambient Milk/STM, 1151001)                        26716.856663
# (FNDM, Ambient Milk/STM, 1151002)                        23192.769997
# (FNDM, Ambient Milk/STM, 1151003)                         3867.464999
# (FNDM, Ambient Milk/STM, 1151004)                          965.430000
# (FNDM, Ambient Milk/STM, 1151005)                       211035.655811
# (FNDM, Ambient Milk/STM, 1151006)                        35194.953331
# (FNDM, Ambient Milk/STM, 1151007)                        27046.506664
# (FNDM, Ambient Milk/STM, 1151008)                         1821.870000
# (FNDM, Ambient Milk/STM, 1151009)                       270974.720020
# (FNDM, Ambient Milk/STM, 1151010)                         5008.146667
# (FNDM, Ambient Milk/STM, 1151011)                         4988.316667
# (FNDM, Ambient Milk/STM, 1151012)                         1433.460000
# (FNDM, Ambient Milk/STM, 1151016)                            0.000000
# (FNDM, Ambient Milk/STM)                                689687.166638
# (FNDM, EVAP, 1110225)                                    35999.950000
# (FNDM, EVAP, 1111503)                                  5213533.769584
# (FNDM, EVAP, 1111516)                                  1256297.425959
# (FNDM, EVAP, 1111517)                                   258899.242945
# (FNDM, EVAP, 1111518)                                    16539.190000
# (FNDM, EVAP, 1111536)                                   746240.754163
# (FNDM, EVAP, 1111545)                                  1173283.600000
# (FNDM, EVAP, 1111741)                                    18789.270000
# (FNDM, EVAP, 1111742)                                     3247.913333
# (FNDM, EVAP)                                           8722831.115984
# (FNDM, SBC, 1111501)                                      1679.399999
# (FNDM, SBC, 1111502)                                    481597.175063
# (FNDM, SBC, 1111521)                                      2909.050000
# (FNDM, SBC, 1111523)                                      5107.100832
# (FNDM, SBC, 1111524)                                      -123.420000
# (FNDM, SBC, 1111528)                                    836978.340000
# (FNDM, SBC, 1111529)                                    116477.817477
# (FNDM, SBC, 1111530)                                    102083.346652
# (FNDM, SBC, 1111531)                                     94638.677503
# (FNDM, SBC, 1111534)                                    327943.223750
# (FNDM, SBC, 1111539)                                      5074.400000
# (FNDM, SBC, 1111541)                                       -37.890000
# (FNDM, SBC, 1111542)                                    666962.707466
# (FNDM, SBC, 1111555)                                    481426.562917
# (FNDM, SBC, 1111556)                                   1146551.065000
# (FNDM, SBC, 1111559)                                     19953.578329
# (FNDM, SBC, 1111781)                                   1611136.712357
# (FNDM, SBC, 1111799)                                    462150.143275
# (FNDM, SBC, 1111804)                                   2175465.113937
# (FNDM, SBC, 1111813)                                     54569.740003
# (FNDM, SBC, 1111817)                                      -834.399999
# (FNDM, SBC, 1111823)                                   2385793.662018
# (FNDM, SBC, 1111824)                                   6575632.823753
# (FNDM, SBC, 1111826)                                   3434086.228161
# (FNDM, SBC, 1111829)                                    104034.885847
# (FNDM, SBC, 1111830)                                   7727037.998535
# (FNDM, SBC, 1111832)                                   1501283.566700
# (FNDM, SBC, 1111844)                                    442887.493276
# (FNDM, SBC, 1111870)                                         0.000000
# (FNDM, SBC, 1111877)                                     75904.905000
# (FNDM, SBC)                                           30838370.007851
# (FNDM, SCM, 1111519)                                     65721.970000
# (FNDM, SCM)                                              65721.970000
# (FNDM, UHT, 1150028)                                      4915.680000
# (FNDM, UHT)                                               4915.680000
# (FNDM)                                                40321525.940473
