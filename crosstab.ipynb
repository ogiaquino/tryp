# %%
import psycopg2

import pandas.io.sql as psql
import numpy as np
import pandas as pd
import parser as pr

#from xlwt import easyxf, Borders, Workbook, Pattern, Style


def data_connection(conn_string):
    conn = psycopg2.connect(conn_string)
    return conn


def data_frame(query, connection):
    df = psql.frame_query(query, con=connection)   
    return df


def crosstabulate(report):
    conn = data_connection(report["conn_str"])
    df = data_frame(report["query"], conn)

    groups = report['groups']
    aggregates = report['aggregates']
    agg = {groups[0]: ['Grand Total']}

    for a in aggregates:
        agg[a[0]] = getattr(df[a[0]], a[1])()
    total = pd.DataFrame(agg)
    total['total_rank'] = 1
    dfs = [total]

    for i in range(1, len(groups)):
        parent_group = groups[:i]
        child_group = groups[i]
        group_total = df.groupby(parent_group, as_index=False).sum()
        group_total[child_group] = group_total[parent_group[-1]].apply(label)
        group_total[parent_group[-1] + '_rank'] = 1
        dfs.append(group_total)
    dfs.append(df.groupby(groups, as_index=False).sum())
    #print dfs[2].to_string()

    # UNION the DataFrames into one DataFrame
    result = pd.concat(dfs)

    # Replace NaNs with empty strings
    result.fillna(dict([(x, '') for x in groups]), inplace=True)
    groups_sort = []
    for x in reversed(groups[:-1]):
        groups_sort.append(result[x + '_rank'].rank())
        groups_sort.append(result[x].rank())
    groups_sort.append(result['total_rank'].rank())

    # Reorder the rows
    sorter = np.lexsort((groups_sort))
    result = result.take(sorter)
    result = result.reindex(columns=groups + [x[0] for x in aggregates])
    return result


def label(ser):
    return '{s} Total'.format(s=ser)


if True:
    reports = pr.parse_tryp("inventory_by_sku.tryp")
    for report in reports:
        ct = crosstabulate(report)

# %%
def label(ser):
    return '{s} Total'.format(s=ser)
pd.set_printoptions(max_columns=100)

# %%
reports = pr.parse_tryp("inventory_by_sku.tryp")
report = reports[1]
conn = data_connection(report["conn_str"])
df = data_frame(report["query"], conn)


columns = ['Region Parent', 'Region', 'Distributor']
rows = ['Category','Brand','SKU']
aggregates=['Sales Qty','Sales Value']
df_items = []

def insert_axes_parent(df_cols, group_length, position='after'):
    df_cols = sorted(df_cols)
    subcols= []                                                                                                                                                               
    for i, col in enumerate(df_cols):                                                                                                                        
        subcols.append(col)                                                                                                                                                      
        if i < len(df_cols) - 1:                                                                                                                           
            for j in reversed(range(-(group_length-1), 0)):                                                                                                                   
                if df_cols[i+1][:j]!=col[:j]:                                                                                                                
                   subcols.append(col[:j])                                                                                                                                      
        else:                                                                                                                                                                
            for j in reversed(range(-(group_length-1), 0)):                                                                                                                   
                subcols.append(col[:j])
    if position=='before':        
        return sorted(reversed(subcols))        
    else:                
        return subcols

for i, cols in enumerate(insert_axes_parent(df.groupby(columns).groups.keys(), len(columns))):    
    for agg in aggregates:
        group = df.groupby(rows + columns[:len(cols)]).sum().unstack(columns[:len(cols)])[agg]
        key = cols + (agg,)
        if len(cols) == 1:  
            df_items.append((key, group[cols[0]]))
        else:              
            df_items.append((key, group[cols]))
    
df = pd.DataFrame.from_items(df_items)

# %%
items = []
print df.axes[1]

for index in insert_axes_parent(df.index, len(rows)): 
    if len(index) < len(rows):                
        items.append((index, np.sum(df.ix[index].fillna(0).values,axis=0)))
    else:        
        items.append((index, df.ix[index]))

tet = pd.DataFrame.from_items(items, orient='index', columns=df.columns)
tet.to_csv('/tmp/tet.csv')

pass the AXES and inser Parent axes
# Out:
# Index([(Peninsular Malaysia, Central, K.Lumpur/P.Jaya, Sales Qty), (Peninsular Malaysia, Central, K.Lumpur/P.Jaya, Sales Value), (Peninsular Malaysia, Central, Seremban, Sales Qty), (Peninsular Malaysia, Central, Seremban, Sales Value), (Peninsular Malaysia, Central, Sales Qty), (Peninsular Malaysia, Central, Sales Value), (Peninsular Malaysia, East Coast, Kota Bahru, Sales Qty), (Peninsular Malaysia, East Coast, Kota Bahru, Sales Value), (Peninsular Malaysia, East Coast, Kuala Terengganu, Sales Qty), (Peninsular Malaysia, East Coast, Kuala Terengganu, Sales Value), (Peninsular Malaysia, East Coast, Kuantan, Sales Qty), (Peninsular Malaysia, East Coast, Kuantan, Sales Value), (Peninsular Malaysia, East Coast, Sales Qty), (Peninsular Malaysia, East Coast, Sales Value), (Peninsular Malaysia, Northern, Alor Setar, Sales Qty), (Peninsular Malaysia, Northern, Alor Setar, Sales Value), (Peninsular Malaysia, Northern, Butterworth, Sales Qty), (Peninsular Malaysia, Northern, Butterworth, Sales Value), (Peninsular Malaysia, Northern, Ipoh, Sales Qty), (Peninsular Malaysia, Northern, Ipoh, Sales Value), (Peninsular Malaysia, Northern, Sales Qty), (Peninsular Malaysia, Northern, Sales Value), (Peninsular Malaysia, Southern, Johor Bahru, Sales Qty), (Peninsular Malaysia, Southern, Johor Bahru, Sales Value), (Peninsular Malaysia, Southern, Melaka, Sales Qty), (Peninsular Malaysia, Southern, Melaka, Sales Value), (Peninsular Malaysia, Southern, Sales Qty), (Peninsular Malaysia, Southern, Sales Value), (Peninsular Malaysia, Sales Qty), (Peninsular Malaysia, Sales Value)], dtype=object)

# %%
#tet.columns
