# %%
import psycopg2

import pandas.io.sql as psql
import numpy as np
import pandas as pd
import parser as pr

#from xlwt import easyxf, Borders, Workbook, Pattern, Style


def data_connection(conn_string):
    conn = psycopg2.connect(conn_string)
    return conn


def data_frame(query, connection):
    df = psql.frame_query(query, con=connection)
    return df


def crosstabulate(report):
    conn = data_connection(report["conn_str"])
    df = data_frame(report["query"], conn)

    groups = report['groups']
    aggregates = report['aggregates']
    agg = {groups[0]: ['Grand Total']}

    for a in aggregates:
        agg[a[0]] = getattr(df[a[0]], a[1])()
    total = pd.DataFrame(agg)
    total['total_rank'] = 1
    dfs = [total]

    for i in range(1, len(groups)):
        parent_group = groups[:i]
        child_group = groups[i]
        group_total = df.groupby(parent_group, as_index=False).sum()
        group_total[child_group] = group_total[parent_group[-1]].apply(label)
        group_total[parent_group[-1] + '_rank'] = 1
        dfs.append(group_total)
    dfs.append(df.groupby(groups, as_index=False).sum())
    #print dfs[2].to_string()

    # UNION the DataFrames into one DataFrame
    result = pd.concat(dfs)

    # Replace NaNs with empty strings
    result.fillna(dict([(x, '') for x in groups]), inplace=True)
    groups_sort = []
    for x in reversed(groups[:-1]):
        groups_sort.append(result[x + '_rank'].rank())
        groups_sort.append(result[x].rank())
    groups_sort.append(result['total_rank'].rank())

    # Reorder the rows
    sorter = np.lexsort((groups_sort))
    result = result.take(sorter)
    result = result.reindex(columns=groups + [x[0] for x in aggregates])
    return result


def label(ser):
    return '{s} Total'.format(s=ser)


#if __name__ == '__main__':
if True:
    reports = pr.parse_tryp("inventory_by_sku.tryp")
    for report in reports:
        ct = crosstabulate(report)
        #print ct.to_string(index=False)

# %%
def label(ser):
    return '{s} Total'.format(s=ser)

# %%
filename = 'paulo.csv'
df = pd.read_csv(filename)

# %%
df_sales = df.groupby(['country','region','area','distributor','salesrep']).sum().unstack(['area','distributor','salesrep'])['sales']

# %%
df_sales
# Out:
# area               Butterworth                              Ipoh                    \
# distributor      HIN MARKETING        KWANG HENG        CORE SYN        SGH EDERAN
# salesrep                   OSE   TLS         LBH   TCS    LILIAN  TEOH       KACEY
# country region
# MY      Central           1000  1000        1000  1000      1000  1000        1000
#         East               NaN   NaN         NaN   NaN       NaN   NaN         NaN
#
# area                           JB                              PJ                  \
# distributor               LEI WAH        WONDER F&B         HEBAT        PENGEDAR
# salesrep         KAMACHI     NF05  NF06        MONC  SEREN   MIGI   OGI      NORM
# country region
# MY      Central     1000      NaN   NaN         NaN    NaN    NaN   NaN       NaN
#         East         NaN     1000  1000        1000   1000   1000  1000      1000
#
# area
# distributor
# salesrep         SIMON
# country region
# MY      Central    NaN
#         East      1000

# %%
df_area_sales = df.groupby(['country','region','area']).sum().unstack(['area'])['sales']

# %%
df_area_sales
# Out:
# area             Butterworth  Ipoh    JB    PJ
# country region
# MY      Central         4000  4000   NaN   NaN
#         East             NaN   NaN  4000  4000

# %%
df_distributor_sales = df.groupby(['country','region','area','distributor']).sum().unstack(['area','distributor'])['sales']

# %%
df_distributor_sales
# Out:
# area               Butterworth                  Ipoh                   JB  \
# distributor      HIN MARKETING  KWANG HENG  CORE SYN  SGH EDERAN  LEI WAH
# country region
# MY      Central           2000        2000      2000        2000      NaN
#         East               NaN         NaN       NaN         NaN     2000
#
# area                            PJ
# distributor      WONDER F&B  HEBAT  PENGEDAR
# country region
# MY      Central         NaN    NaN       NaN
#         East           2000   2000      2000

# %%
df_salesrep_sales = df.groupby(['country','region','area','distributor','salesrep']).sum().unstack(['area','distributor','salesrep'])['sales']

# %%
df_salesrep_sales
# Out:
# area               Butterworth                              Ipoh                    \
# distributor      HIN MARKETING        KWANG HENG        CORE SYN        SGH EDERAN
# salesrep                   OSE   TLS         LBH   TCS    LILIAN  TEOH       KACEY
# country region
# MY      Central           1000  1000        1000  1000      1000  1000        1000
#         East               NaN   NaN         NaN   NaN       NaN   NaN         NaN
#
# area                           JB                              PJ                  \
# distributor               LEI WAH        WONDER F&B         HEBAT        PENGEDAR
# salesrep         KAMACHI     NF05  NF06        MONC  SEREN   MIGI   OGI      NORM
# country region
# MY      Central     1000      NaN   NaN         NaN    NaN    NaN   NaN       NaN
#         East         NaN     1000  1000        1000   1000   1000  1000      1000
#
# area
# distributor
# salesrep         SIMON
# country region
# MY      Central    NaN
#         East      1000

# %%
df_salesrep_sales
# Out:
# area               Butterworth                              Ipoh                    \
# distributor      HIN MARKETING        KWANG HENG        CORE SYN        SGH EDERAN
# salesrep                   OSE   TLS         LBH   TCS    LILIAN  TEOH       KACEY
# country region
# MY      Central           1000  1000        1000  1000      1000  1000        1000
#         East               NaN   NaN         NaN   NaN       NaN   NaN         NaN
#
# area                           JB                              PJ                  \
# distributor               LEI WAH        WONDER F&B         HEBAT        PENGEDAR
# salesrep         KAMACHI     NF05  NF06        MONC  SEREN   MIGI   OGI      NORM
# country region
# MY      Central     1000      NaN   NaN         NaN    NaN    NaN   NaN       NaN
#         East         NaN     1000  1000        1000   1000   1000  1000      1000
#
# area
# distributor
# salesrep         SIMON
# country region
# MY      Central    NaN
#         East      1000

# %%
pd.DataFrame(
    {
        (0,'Butterworth','HIN MARKETING','OSE'):df_salesrep_sales[('Butterworth','HIN MARKETING','OSE')],
        (1,'Butterworth','HIN MARKETING','TLS'):df_salesrep_sales[('Butterworth','HIN MARKETING','TLS')],
        (2,'Butterworth','HIN MARKETING'):df_distributor_sales[('Butterworth','HIN MARKETING')], 
        (3,'Butterworth','KWANG HENG','LBH'):df_salesrep_sales[('Butterworth','KWANG HENG','LBH')],
        (4,'Butterworth','KWANG HENG','TCS'):df_salesrep_sales[('Butterworth','KWANG HENG','TCS')],
        (5,'Butterworth','KWANG HENG'):df_distributor_sales[('Butterworth','KWANG HENG')],
        (6,'Butterworth'):df_area_sales[('Butterworth')],
        (7,'Ipoh','CORE SYN','LILIAN'):df_salesrep_sales[('Ipoh','CORE SYN','LILIAN')],
        (8,'Ipoh','CORE SYN','TEOH'):df_salesrep_sales[('Ipoh','CORE SYN','TEOH')],
        (9,'Ipoh','CORE SYN'):df_distributor_sales[('Ipoh','CORE SYN')], 
        (10,'Ipoh','SGH EDERAN','KACEY'):df_salesrep_sales[('Ipoh','SGH EDERAN','KACEY')],
        (11,'Ipoh','SGH EDERAN','KAMACHI'):df_salesrep_sales[('Ipoh','SGH EDERAN','KAMACHI')],
        (12,'Ipoh','SGH EDERAN'):df_distributor_sales[('Ipoh','SGH EDERAN')],
        (13,'Ipoh'):df_area_sales[('Ipoh')],  
        
    }
)
# Out:
#                  (0, Butterworth, HIN MARKETING, OSE)  \
# country region
# MY      Central                                  1000
#         East                                      NaN
#
#                  (1, Butterworth, HIN MARKETING, TLS)  \
# country region
# MY      Central                                  1000
#         East                                      NaN
#
#                  (2, Butterworth, HIN MARKETING)  \
# country region
# MY      Central                             2000
#         East                                 NaN
#
#                  (3, Butterworth, KWANG HENG, LBH)  \
# country region
# MY      Central                               1000
#         East                                   NaN
#
#                  (4, Butterworth, KWANG HENG, TCS)  (5, Butterworth, KWANG HENG)  \
# country region
# MY      Central                               1000                          2000
#         East                                   NaN                           NaN
#
#                  (6, Butterworth)  (7, Ipoh, CORE SYN, LILIAN)  \
# country region
# MY      Central              4000                         1000
#         East                  NaN                          NaN
#
#                  (8, Ipoh, CORE SYN, TEOH)  (9, Ipoh, CORE SYN)  \
# country region
# MY      Central                       1000                 2000
#         East                           NaN                  NaN
#
#                  (10, Ipoh, SGH EDERAN, KACEY)  (11, Ipoh, SGH EDERAN, KAMACHI)  \
# country region
# MY      Central                           1000                             1000
#         East                               NaN                              NaN
#
#                  (12, Ipoh, SGH EDERAN)  (13, Ipoh)
# country region
# MY      Central                    2000        4000
#         East                        NaN         NaN

# %%
print df_salesrep_sales.append(df_distributor_sales).to_string()
# Out:
#                    Butterworth                                                                        Ipoh                                                               JB                                                           PJ
#                  HIN MARKETING  HIN MARKETING  HIN MARKETING  KWANG HENG  KWANG HENG  KWANG HENG  CORE SYN  CORE SYN  CORE SYN  SGH EDERAN  SGH EDERAN  SGH EDERAN  LEI WAH  LEI WAH  LEI WAH  WONDER F&B  WONDER F&B  WONDER F&B  HEBAT  HEBAT  HEBAT  PENGEDAR  PENGEDAR  PENGEDAR
# country region
# MY      Central            NaN            NaN            NaN         NaN         NaN         NaN       NaN       NaN       NaN         NaN         NaN         NaN      NaN      NaN      NaN         NaN         NaN         NaN    NaN    NaN    NaN       NaN       NaN       NaN
#         East               NaN            NaN            NaN         NaN         NaN         NaN       NaN       NaN       NaN         NaN         NaN         NaN      NaN      NaN      NaN         NaN         NaN         NaN    NaN    NaN    NaN       NaN       NaN       NaN
#         Central           2000           2000           2000        2000        2000        2000      2000      2000      2000        2000        2000        2000      NaN      NaN      NaN         NaN         NaN         NaN    NaN    NaN    NaN       NaN       NaN       NaN
#         East               NaN            NaN            NaN         NaN         NaN         NaN       NaN       NaN       NaN         NaN         NaN         NaN     2000     2000     2000        2000        2000        2000   2000   2000   2000      2000      2000      2000

# %%
df_salesrep_sales.keys()
# Out:
# MultiIndex
# [(Butterworth, HIN MARKETING, OSE), (Butterworth, HIN MARKETING, TLS), (Butterworth, KWANG HENG, LBH), (Butterworth, KWANG HENG, TCS), (Ipoh, CORE SYN, LILIAN), (Ipoh, CORE SYN, TEOH), (Ipoh, SGH EDERAN, KACEY), (Ipoh, SGH EDERAN, KAMACHI), (JB, LEI WAH, NF05), (JB, LEI WAH, NF06), (JB, WONDER F&B, MONC), (JB, WONDER F&B, SEREN), (PJ, HEBAT, MIGI), (PJ, HEBAT, OGI), (PJ, PENGEDAR, NORM), (PJ, PENGEDAR, SIMON)]

# %%
groups = ['area','distributor','salesrep']

paulo = []

print -(len(groups)-1)
for x,y in enumerate(df_salesrep_sales.columns):
    
    
    paulo.append(y)
    if x < len(df_salesrep_sales.columns) - 1:
        for z in reversed(range(-(len(groups)-1), 0)):
            if df_salesrep_sales.columns[x+1][:z]!=y[:z]:
                paulo.append(y[:z])
                #paulo.insert(0,y[:z])
        
    else:
        for z in reversed(range(-(len(groups)-1), 0)):
            paulo.append(y[:z])
            #paulo.insert(0,y[:z])

for x in paulo:
    print x
# Out:
# -2
# ('Butterworth', 'HIN MARKETING', 'OSE')
# ('Butterworth', 'HIN MARKETING', 'TLS')
# ('Butterworth', 'HIN MARKETING')
# ('Butterworth', 'KWANG HENG', 'LBH')
# ('Butterworth', 'KWANG HENG', 'TCS')
# ('Butterworth', 'KWANG HENG')
# ('Butterworth',)
# ('Ipoh', 'CORE SYN', 'LILIAN')
# ('Ipoh', 'CORE SYN', 'TEOH')
# ('Ipoh', 'CORE SYN')
# ('Ipoh', 'SGH EDERAN', 'KACEY')
# ('Ipoh', 'SGH EDERAN', 'KAMACHI')
# ('Ipoh', 'SGH EDERAN')
# ('Ipoh',)
# ('JB', 'LEI WAH', 'NF05')
# ('JB', 'LEI WAH', 'NF06')
# ('JB', 'LEI WAH')
# ('JB', 'WONDER F&B', 'MONC')
# ('JB', 'WONDER F&B', 'SEREN')
# ('JB', 'WONDER F&B')
# ('JB',)
# ('PJ', 'HEBAT', 'MIGI')
# ('PJ', 'HEBAT', 'OGI')
# ('PJ', 'HEBAT')
# ('PJ', 'PENGEDAR', 'NORM')
# ('PJ', 'PENGEDAR', 'SIMON')
# ('PJ', 'PENGEDAR')
# ('PJ',)

# %%
ds.groups
# Out:
#                  (0, Butterworth, HIN MARKETING, OSE)  \
# country region
# MY      Central                                  1000
#         East                                      NaN
#
#                  (1, Butterworth, HIN MARKETING, TLS)  \
# country region
# MY      Central                                  1000
#         East                                      NaN
#
#                  (2, Butterworth, HIN MARKETING)  \
# country region
# MY      Central                             2000
#         East                                 NaN
#
#                  (3, Butterworth, KWANG HENG, LBH)  \
# country region
# MY      Central                               1000
#         East                                   NaN
#
#                  (4, Butterworth, KWANG HENG, TCS)  (5, Butterworth, KWANG HENG)  \
# country region
# MY      Central                               1000                          2000
#         East                                   NaN                           NaN
#
#                  (6, Butterworth)  (7, Ipoh, CORE SYN, LILIAN)  \
# country region
# MY      Central              4000                         1000
#         East                  NaN                          NaN
#
#                  (8, Ipoh, CORE SYN, TEOH)  (9, Ipoh, CORE SYN)  \
# country region
# MY      Central                       1000                 2000
#         East                           NaN                  NaN
#
#                  (10, Ipoh, SGH EDERAN, KACEY)  (11, Ipoh, SGH EDERAN, KAMACHI)  \
# country region
# MY      Central                           1000                             1000
#         East                               NaN                              NaN
#
#                  (12, Ipoh, SGH EDERAN)  (13, Ipoh)
# country region
# MY      Central                    2000        4000
#         East                        NaN         NaN

# %%
[x for x in reversed(range(-2, 0))]
# Out:
# [-1, -2]
