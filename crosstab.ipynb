# %%
import psycopg2

import pandas.io.sql as psql
import numpy as np
import pandas as pd
import parser as pr

#from xlwt import easyxf, Borders, Workbook, Pattern, Style


def data_connection(conn_string):
    conn = psycopg2.connect(conn_string)
    return conn


def data_frame(query, connection):
    df = psql.frame_query(query, con=connection)
    return df


def crosstabulate(report):
    conn = data_connection(report["conn_str"])
    df = data_frame(report["query"], conn)

    groups = report['groups']
    aggregates = report['aggregates']
    agg = {groups[0]: ['Grand Total']}

    for a in aggregates:
        agg[a[0]] = getattr(df[a[0]], a[1])()
    total = pd.DataFrame(agg)
    total['total_rank'] = 1
    dfs = [total]

    for i in range(1, len(groups)):
        parent_group = groups[:i]
        child_group = groups[i]
        group_total = df.groupby(parent_group, as_index=False).sum()
        group_total[child_group] = group_total[parent_group[-1]].apply(label)
        group_total[parent_group[-1] + '_rank'] = 1
        dfs.append(group_total)
    dfs.append(df.groupby(groups, as_index=False).sum())
    #print dfs[2].to_string()

    # UNION the DataFrames into one DataFrame
    result = pd.concat(dfs)

    # Replace NaNs with empty strings
    result.fillna(dict([(x, '') for x in groups]), inplace=True)
    groups_sort = []
    for x in reversed(groups[:-1]):
        groups_sort.append(result[x + '_rank'].rank())
        groups_sort.append(result[x].rank())
    groups_sort.append(result['total_rank'].rank())

    # Reorder the rows
    sorter = np.lexsort((groups_sort))
    result = result.take(sorter)
    result = result.reindex(columns=groups + [x[0] for x in aggregates])
    return result


def label(ser):
    return '{s} Total'.format(s=ser)


#if __name__ == '__main__':
if True:
    reports = pr.parse_tryp("inventory_by_sku.tryp")
    for report in reports:
        ct = crosstabulate(report)
        #print ct.to_string(index=False)

# %%
def label(ser):
    return '{s} Total'.format(s=ser)

# %%
filename = 'paulo.csv'
df = pd.read_csv(filename)

# %%
df_sales = df.groupby(['country','region','area','distributor','salesrep']).sum().unstack(['area','distributor','salesrep'])['sales']

# %%
df_sales
# Out:
# area               Butterworth                              Ipoh                    \
# distributor      HIN MARKETING        KWANG HENG        CORE SYN        SGH EDERAN
# salesrep                   OSE   TLS         LBH   TCS    LILIAN  TEOH       KACEY
# country region
# MY      Central           1000  1000        1000  1000      1000  1000        1000
#         East               NaN   NaN         NaN   NaN       NaN   NaN         NaN
#
# area                           JB                              PJ                  \
# distributor               LEI WAH        WONDER F&B         HEBAT        PENGEDAR
# salesrep         KAMACHI     NF05  NF06        MONC  SEREN   MIGI   OGI      NORM
# country region
# MY      Central     1000      NaN   NaN         NaN    NaN    NaN   NaN       NaN
#         East         NaN     1000  1000        1000   1000   1000  1000      1000
#
# area
# distributor
# salesrep         SIMON
# country region
# MY      Central    NaN
#         East      1000

# %%
df_area_sales = df.groupby(['country','region','area']).sum().unstack(['area'])['sales']

# %%
df_area_sales
# Out:
# area             Butterworth  Ipoh    JB    PJ
# country region
# MY      Central         4000  4000   NaN   NaN
#         East             NaN   NaN  4000  4000

# %%
df_distributor_sales = df.groupby(['country','region','area','distributor']).sum().unstack(['area','distributor'])['sales']

# %%
df_distributor_sales
# Out:
# area               Butterworth                  Ipoh                   JB  \
# distributor      HIN MARKETING  KWANG HENG  CORE SYN  SGH EDERAN  LEI WAH
# country region
# MY      Central           2000        2000      2000        2000      NaN
#         East               NaN         NaN       NaN         NaN     2000
#
# area                            PJ
# distributor      WONDER F&B  HEBAT  PENGEDAR
# country region
# MY      Central         NaN    NaN       NaN
#         East           2000   2000      2000

# %%
df_salesrep_sales = df.groupby(['country','region','area','distributor','salesrep']).sum().unstack(['region','area','distributor','salesrep'])['sales']

# %%
df_salesrep_sales
# Out:
# region             Central                                                      \
# area           Butterworth                              Ipoh
# distributor  HIN MARKETING        KWANG HENG        CORE SYN        SGH EDERAN
# salesrep               OSE   TLS         LBH   TCS    LILIAN  TEOH       KACEY
# country
# MY                    1000  1000        1000  1000      1000  1000        1000
#
# region                   East
# area                       JB                              PJ
# distributor           LEI WAH        WONDER F&B         HEBAT        PENGEDAR
# salesrep     KAMACHI     NF05  NF06        MONC  SEREN   MIGI   OGI      NORM  SIMON
# country
# MY              1000     1000  1000        1000   1000   1000  1000      1000   1000

# %%
df_salesrep_sales.columns
# Out:
# MultiIndex
# [(Central, Butterworth, HIN MARKETING, OSE), (Central, Butterworth, HIN MARKETING, TLS), (Central, Butterworth, KWANG HENG, LBH), (Central, Butterworth, KWANG HENG, TCS), (Central, Ipoh, CORE SYN, LILIAN), (Central, Ipoh, CORE SYN, TEOH), (Central, Ipoh, SGH EDERAN, KACEY), (Central, Ipoh, SGH EDERAN, KAMACHI), (East, JB, LEI WAH, NF05), (East, JB, LEI WAH, NF06), (East, JB, WONDER F&B, MONC), (East, JB, WONDER F&B, SEREN), (East, PJ, HEBAT, MIGI), (East, PJ, HEBAT, OGI), (East, PJ, PENGEDAR, NORM), (East, PJ, PENGEDAR, SIMON)]

# %%
pd.DataFrame(
    {
        (0,'Butterworth','HIN MARKETING','OSE'):df_salesrep_sales[('Butterworth','HIN MARKETING','OSE')],
        (1,'Butterworth','HIN MARKETING','TLS'):df_salesrep_sales[('Butterworth','HIN MARKETING','TLS')],
        (2,'Butterworth','HIN MARKETING'):df_distributor_sales[('Butterworth','HIN MARKETING')], 
        (3,'Butterworth','KWANG HENG','LBH'):df_salesrep_sales[('Butterworth','KWANG HENG','LBH')],
        (4,'Butterworth','KWANG HENG','TCS'):df_salesrep_sales[('Butterworth','KWANG HENG','TCS')],
        (5,'Butterworth','KWANG HENG'):df_distributor_sales[('Butterworth','KWANG HENG')],
        (6,'Butterworth'):df_area_sales[('Butterworth')],
        (7,'Ipoh','CORE SYN','LILIAN'):df_salesrep_sales[('Ipoh','CORE SYN','LILIAN')],
        (8,'Ipoh','CORE SYN','TEOH'):df_salesrep_sales[('Ipoh','CORE SYN','TEOH')],
        (9,'Ipoh','CORE SYN'):df_distributor_sales[('Ipoh','CORE SYN')], 
        (10,'Ipoh','SGH EDERAN','KACEY'):df_salesrep_sales[('Ipoh','SGH EDERAN','KACEY')],
        (11,'Ipoh','SGH EDERAN','KAMACHI'):df_salesrep_sales[('Ipoh','SGH EDERAN','KAMACHI')],
        (12,'Ipoh','SGH EDERAN'):df_distributor_sales[('Ipoh','SGH EDERAN')],
        (13,'Ipoh'):df_area_sales[('Ipoh')],  
        
    }
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-261-9753766d2309> in <module>()
#       1 pd.DataFrame(
#       2     {
# ----> 3         (0,'Butterworth','HIN MARKETING','OSE'):df_salesrep_sales[('Butterworth','HIN MARKETING','OSE')],
#       4         (1,'Butterworth','HIN MARKETING','TLS'):df_salesrep_sales[('Butterworth','HIN MARKETING','TLS')],
#       5         (2,'Butterworth','HIN MARKETING'):df_distributor_sales[('Butterworth','HIN MARKETING')],
#
# /home/ogi/tryp/virtualenv/local/lib/python2.7/site-packages/pandas-0.10.1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_array(key)
#    1963         elif isinstance(self.columns, MultiIndex):
# -> 1964             return self._getitem_multilevel(key)
#    1965         elif isinstance(key, DataFrame):
#    1966             if key.values.dtype == bool:
#
# /home/ogi/tryp/virtualenv/local/lib/python2.7/site-packages/pandas-0.10.1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in _getitem_multilevel(self, key)
#    2008
#    2009     def _getitem_multilevel(self, key):
# -> 2010         loc = self.columns.get_loc(key)
#    2011         if isinstance(loc, (slice, np.ndarray)):
#    2012             new_columns = self.columns[loc]
#
# /home/ogi/tryp/virtualenv/local/lib/python2.7/site-packages/pandas-0.10.1-py2.7-linux-x86_64.egg/pandas/core/index.pyc in get_loc(self, key)
#    2174                 result = slice(*self.slice_locs(key, key))
#    2175                 if result.start == result.stop:
# -> 2176                     raise KeyError(key)
#    2177                 return result
#    2178         else:
#
# KeyError: ('Butterworth', 'HIN MARKETING', 'OSE')

# %%
filename = 'paulo.csv'
df = pd.read_csv(filename)


columns = ['area', 'distributor', 'salesrep']
rows = ['country', 'region']





def subcolumns(df_cols, group_length,reverse=False):                                                                                                                                       
                                                                                                                                                                             
    subcols= []                                                                                                                                                               
    for i, col in enumerate(df_cols):                                                                                                                        
        subcols.append(col)                                                                                                                                                      
        if i < len(df_cols) - 1:                                                                                                                           
            for j in reversed(range(-(group_length-1), 0)):                                                                                                                   
                if df_cols[i+1][:j]!=col[:j]:                                                                                                                
                   subcols.append(col[:j])                                                                                                                                      
        else:                                                                                                                                                                
            for j in reversed(range(-(group_length-1), 0)):                                                                                                                   
                subcols.append(col[:j])
    if reverse:        
        return sorted(reversed(subcols))        
    else:
        return subcols

new_df = {}
df_all = df.groupby(rows+columns).sum().unstack(columns)['sales']

aggregates = ['sales','invoice_count']

for i, cols in enumerate(subcolumns(df_all.columns,len(columns))):
    for agg in aggregates:
        group = df.groupby(rows+columns[:len(cols)]).sum().unstack(columns[:len(cols)])[agg]
        key = list(cols)
        key.append(agg)    
        if len(cols) == 1:        
            new_df[tuple(key)] = group[cols[0]]
        else:
            new_df[tuple(key)] = group[cols]
    
#print new_df
pd.DataFrame.from_dict(new_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2 entries, (MY, Central) to (MY, East)
# Data columns:
# (Butterworth, HIN MARKETING, OSE, invoice_count)    1  non-null values
# (Butterworth, HIN MARKETING, OSE, sales)            1  non-null values
# (Butterworth, HIN MARKETING, TLS, invoice_count)    1  non-null values
# (Butterworth, HIN MARKETING, TLS, sales)            1  non-null values
# (Butterworth, HIN MARKETING, invoice_count)         1  non-null values
# (Butterworth, HIN MARKETING, sales)                 1  non-null values
# (Butterworth, KWANG HENG, LBH, invoice_count)       1  non-null values
# (Butterworth, KWANG HENG, LBH, sales)               1  non-null values
# (Butterworth, KWANG HENG, TCS, invoice_count)       1  non-null values
# (Butterworth, KWANG HENG, TCS, sales)               1  non-null values
# (Butterworth, KWANG HENG, invoice_count)            1  non-null values
# (Butterworth, KWANG HENG, sales)                    1  non-null values
# (Butterworth, invoice_count)                        1  non-null values
# (Butterworth, sales)                                1  non-null values
# (Ipoh, CORE SYN, LILIAN, invoice_count)             1  non-null values
# (Ipoh, CORE SYN, LILIAN, sales)                     1  non-null values
# (Ipoh, CORE SYN, TEOH, invoice_count)               1  non-null values
# (Ipoh, CORE SYN, TEOH, sales)                       1  non-null values
# (Ipoh, CORE SYN, invoice_count)                     1  non-null values
# (Ipoh, CORE SYN, sales)                             1  non-null values
# (Ipoh, SGH EDERAN, KACEY, invoice_count)            1  non-null values
# (Ipoh, SGH EDERAN, KACEY, sales)                    1  non-null values
# (Ipoh, SGH EDERAN, KAMACHI, invoice_count)          1  non-null values
# (Ipoh, SGH EDERAN, KAMACHI, sales)                  1  non-null values
# (Ipoh, SGH EDERAN, invoice_count)                   1  non-null values
# (Ipoh, SGH EDERAN, sales)                           1  non-null values
# (Ipoh, invoice_count)                               1  non-null values
# (Ipoh, sales)                                       1  non-null values
# (JB, LEI WAH, NF05, invoice_count)                  1  non-null values
# (JB, LEI WAH, NF05, sales)                          1  non-null values
# (JB, LEI WAH, NF06, invoice_count)                  1  non-null values
# (JB, LEI WAH, NF06, sales)                          1  non-null values
# (JB, LEI WAH, invoice_count)                        1  non-null values
# (JB, LEI WAH, sales)                                1  non-null values
# (JB, WONDER F&B, MONC, invoice_count)               1  non-null values
# (JB, WONDER F&B, MONC, sales)                       1  non-null values
# (JB, WONDER F&B, SEREN, invoice_count)              1  non-null values
# (JB, WONDER F&B, SEREN, sales)                      1  non-null values
# (JB, WONDER F&B, invoice_count)                     1  non-null values
# (JB, WONDER F&B, sales)                             1  non-null values
# (JB, invoice_count)                                 1  non-null values
# (JB, sales)                                         1  non-null values
# (PJ, HEBAT, MIGI, invoice_count)                    1  non-null values
# (PJ, HEBAT, MIGI, sales)                            1  non-null values
# (PJ, HEBAT, OGI, invoice_count)                     1  non-null values
# (PJ, HEBAT, OGI, sales)                             1  non-null values
# (PJ, HEBAT, invoice_count)                          1  non-null values
# (PJ, HEBAT, sales)                                  1  non-null values
# (PJ, PENGEDAR, NORM, invoice_count)                 1  non-null values
# (PJ, PENGEDAR, NORM, sales)                         1  non-null values
# (PJ, PENGEDAR, SIMON, invoice_count)                1  non-null values
# (PJ, PENGEDAR, SIMON, sales)                        1  non-null values
# (PJ, PENGEDAR, invoice_count)                       1  non-null values
# (PJ, PENGEDAR, sales)                               1  non-null values
# (PJ, invoice_count)                                 1  non-null values
# (PJ, sales)                                         1  non-null values
# dtypes: float64(56)

# %%
paulo.columns
# Out:
# Index([(Butterworth, HIN MARKETING, OSE, invoice_count), (Butterworth, HIN MARKETING, OSE, sales), (Butterworth, HIN MARKETING, TLS, invoice_count), (Butterworth, HIN MARKETING, TLS, sales), (Butterworth, HIN MARKETING, invoice_count), (Butterworth, HIN MARKETING, sales), (Butterworth, KWANG HENG, LBH, invoice_count), (Butterworth, KWANG HENG, LBH, sales), (Butterworth, KWANG HENG, TCS, invoice_count), (Butterworth, KWANG HENG, TCS, sales), (Butterworth, KWANG HENG, invoice_count), (Butterworth, KWANG HENG, sales), (Butterworth, invoice_count), (Butterworth, sales), (Ipoh, CORE SYN, LILIAN, invoice_count), (Ipoh, CORE SYN, LILIAN, sales), (Ipoh, CORE SYN, TEOH, invoice_count), (Ipoh, CORE SYN, TEOH, sales), (Ipoh, CORE SYN, invoice_count), (Ipoh, CORE SYN, sales), (Ipoh, SGH EDERAN, KACEY, invoice_count), (Ipoh, SGH EDERAN, KACEY, sales), (Ipoh, SGH EDERAN, KAMACHI, invoice_count), (Ipoh, SGH EDERAN, KAMACHI, sales), (Ipoh, SGH EDERAN, invoice_count), (Ipoh, SGH EDERAN, sales), (Ipoh, invoice_count), (Ipoh, sales), (JB, LEI WAH, NF05, invoice_count), (JB, LEI WAH, NF05, sales), (JB, LEI WAH, NF06, invoice_count), (JB, LEI WAH, NF06, sales), (JB, LEI WAH, invoice_count), (JB, LEI WAH, sales), (JB, WONDER F&B, MONC, invoice_count), (JB, WONDER F&B, MONC, sales), (JB, WONDER F&B, SEREN, invoice_count), (JB, WONDER F&B, SEREN, sales), (JB, WONDER F&B, invoice_count), (JB, WONDER F&B, sales), (JB, invoice_count), (JB, sales), (PJ, HEBAT, MIGI, invoice_count), (PJ, HEBAT, MIGI, sales), (PJ, HEBAT, OGI, invoice_count), (PJ, HEBAT, OGI, sales), (PJ, HEBAT, invoice_count), (PJ, HEBAT, sales), (PJ, PENGEDAR, NORM, invoice_count), (PJ, PENGEDAR, NORM, sales), (PJ, PENGEDAR, SIMON, invoice_count), (PJ, PENGEDAR, SIMON, sales), (PJ, PENGEDAR, invoice_count), (PJ, PENGEDAR, sales), (PJ, invoice_count), (PJ, sales)], dtype=object)
